# %%
import pandas as pd
#series
s = pd.Series([1,2,3,4,5])
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
dict_data = {'a':1,'b':2,'c':3}

series_data = pd.Series(dict_data)
print(series_data)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [1,2,3,4,"crest"]
index = ['emp-1','emp-2','emp-3','emp-4','emp-5']

series_data = pd.Series(data,index=index)
type(series_data)
# Out:
# pandas.core.series.Series

# %%
#dataframe
data= {
    "name":["vatsal","vraj","aneri","prince"],
    "age":[21,22,23,None]
}
df = pd.DataFrame(data)
df
# Out:
#      name   age
# 0  vatsal  21.0
# 1    vraj  22.0
# 2   aneri  23.0
# 3  prince   NaN

# %%
df.loc[1]
# Out:
# name    vraj
# age     22.0
# Name: 1, dtype: object

# %%
df['salary']=[200000,300000,50000,60000]
# Out:
#      name   age  salary
# 0  vatsal  21.0  200000
# 1    vraj  22.0  300000
# 2   aneri  23.0   50000
# 3  prince   NaN   60000

# %%
df['salary'] = [10000,300000,50000,60000]
df
# Out:
#      name   age  salary
# 0  vatsal  21.0   10000
# 1    vraj  22.0  300000
# 2   aneri  23.0   50000
# 3  prince   NaN   60000

# %%
df.describe()
# Out:
#         age         salary
# count   3.0       4.000000
# mean   22.0  105000.000000
# std     1.0  131782.649338
# min    21.0   10000.000000
# 25%    21.5   40000.000000
# 50%    22.0   55000.000000
# 75%    22.5  120000.000000
# max    23.0  300000.000000

# %%
df = pd.read_csv("sales1_data.csv")
df.isnull().sum()
# Out:
# Date       0
# Product    0
# Sales      6
# Region     0
# dtype: int64

# %%
df.head(5)
# Out:
#          Date   Product  Sales Region
# 0  2023-01-01  Product3  738.0   West
# 1  2023-01-02  Product2  868.0  North
# 2  2023-01-03  Product2  554.0   West
# 3  2023-01-04  Product1  618.0  South
# 4  2023-01-05  Product3  501.0   East

# %%
df['filled_sales'] = df['Sales'].fillna(df['Sales'].mean())
df['Sales'] = df['filled_sales']
df.drop(['filled_sales'],inplace=True,axis=1)

# %%
df.isna().sum()
# Out:
# Date       0
# Product    0
# Sales      0
# Region     0
# dtype: int64

# %%
df = pd.DataFrame({'W':[68,75,86,80,None],'X':[78,75,None,80,86], 'Y':[84,94,89,86,86],'Z':[86,97,96,72,83]})
sr_data = pd.Series([68, 75, 86, 80, None]) 
df.eq(sr_data,axis=0)
# Out:
#        W      X      Y      Z
# 0   True  False  False  False
# 1   True   True  False  False
# 2   True  False  False  False
# 3   True   True  False  False
# 4  False  False  False  False

# %%
series1 = pd.Series(range(10))
series2 = pd.Series(list('pqrstuvwxy'))
pd.concat([series1,series2],axis=1)
# Out:
#    0  1
# 0  0  p
# 1  1  q
# 2  2  r
# 3  3  s
# 4  4  t
# 5  5  u
# 6  6  v
# 7  7  w
# 8  8  x
# 9  9  y

# %%
result = pd.Series(pd.date_range('2020-01-01', periods=52, freq='W-SUN'))
result
# Out:
# 0    2020-01-05
# 1    2020-01-12
# 2    2020-01-19
# 3    2020-01-26
# 4    2020-02-02
# 5    2020-02-09
# 6    2020-02-16
# 7    2020-02-23
# 8    2020-03-01
# 9    2020-03-08
# 10   2020-03-15
# 11   2020-03-22
# 12   2020-03-29
# 13   2020-04-05
# 14   2020-04-12
# 15   2020-04-19
# 16   2020-04-26
# 17   2020-05-03
# 18   2020-05-10
# 19   2020-05-17
# 20   2020-05-24
# 21   2020-05-31
# 22   2020-06-07
# 23   2020-06-14
# 24   2020-06-21
# 25   2020-06-28
# 26   2020-07-05
# 27   2020-07-12
# 28   2020-07-19
# 29   2020-07-26
# 30   2020-08-02
# 31   2020-08-09
# 32   2020-08-16
# 33   2020-08-23
# 34   2020-08-30
# 35   2020-09-06
# 36   2020-09-13
# 37   2020-09-20
# 38   2020-09-27
# 39   2020-10-04
# 40   2020-10-11
# 41   2020-10-18
# 42   2020-10-25
# 43   2020-11-01
# 44   2020-11-08
# 45   2020-11-15
# 46   2020-11-22
# 47   2020-11-29
# 48   2020-12-06
# 49   2020-12-13
# 50   2020-12-20
# 51   2020-12-27
# dtype: datetime64[ns]

# %%
str1 = 'abc def abcdef icd'

ser = pd.Series(list(str1))
element_freq = ser.value_counts()


"".join(ser)
# Out:
# 'abc def abcdef icd'

# %%
d = {'col1': [1, 2, 3, 4, 7, 11], 'col2': [4, 5, 6, 9, 5, 0], 'col3': [7, 5, 8, 12, 1,11]}
df = pd.DataFrame(data=d)
print(df)
df.nlargest(4,'col1')
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11
#    col1  col2  col3
# 5    11     0    11
# 4     7     5     1
# 3     4     9    12
# 2     3     6     8

# %%
df1 = pd.DataFrame({'W':[68,75,86,80,None],'X':[78,85,None,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]});
df2 = pd.DataFrame({'W':[78,75,86,80,None],'X':[78,85,96,80,76], 'Y':[84,84,89,83,86],'Z':[86,97,96,72,83]});
print("Original DataFrames:")
print(df1)
print(df2)
print("\nCheck for inequality of the said dataframes:")
print(df1.ne(df2))
# Out:
# Original DataFrames:
#       W     X   Y   Z
# 0  68.0  78.0  84  86
# 1  75.0  85.0  94  97
# 2  86.0   NaN  89  96
# 3  80.0  80.0  83  72
# 4   NaN  86.0  86  83
#       W   X   Y   Z
# 0  78.0  78  84  86
# 1  75.0  85  84  97
# 2  86.0  96  89  96
# 3  80.0  80  83  72
# 4   NaN  76  86  83
#
# Check for inequality of the said dataframes:
#        W      X      Y      Z
# 0   True  False  False  False
# 1  False  False   True  False
# 2  False   True  False  False
# 3  False  False  False  False
# 4   True   True  False  False

# %%
df1=pd.DataFrame({'rnum':[23, 21, 27, 22, 34, 33, 34, 31, 25, 22, 34, 19, 31, 32, 19]})
Max = df1['rnum'][0]

for i,j in enumerate(df1['rnum']):
    if Max<=j:
        Max=j
    if j<Max:
        
        df1['rnum'][i]=0
df1
# Out:
# C:\Users\VatsalChauhan\AppData\Local\Temp\ipykernel_12044\2230395203.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1['rnum'][i]=0
#     rnum
# 0     23
# 1      0
# 2     27
# 3      0
# 4     34
# 5      0
# ...

# %%
sr1 = pd.Series(['php', 'python', 'java', 'c#', 'c++'])
sr2 = pd.Series([1, 2, 3, 4, 5])

# %%
df = pd.DataFrame({
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Syed Wharton', 'Kierra Gentry'],
      'age': [18, 22, 85, 50, 80, 5]
})


df["age_groups"] = pd.cut(df["age"],bins=[0,18,65,99],labels = ["kids", "adult", "elderly"])
df["age_groups"]
# Out:
# 0       kids
# 1      adult
# 2    elderly
# 3      adult
# 4    elderly
# 5       kids
# Name: age_groups, dtype: category
# Categories (3, object): ['kids' < 'adult' < 'elderly']

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 37, 33, 30, 31, 32],
    'tcode': ['t1', 't2', 't3', 't4', 't5', 't6']}) 
df = df.set_index(['school_code'])
print(df.query("tcode == 't2'"))
print(df.query("school_code == 's001'"))
# Out:
#             class          name date_of_birth  weight tcode
# school_code
# s002            V  Gino Mcneill    17/05/2002      37    t2
#             class            name date_of_birth  weight tcode
# school_code
# s001            V  Alberto Franco    15/05/2002      35    t1
# s001           VI    Eesha Hinton    25/09/1998      30    t4

# %%
import numpy as np
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, None, 33, 30, 31, None]},
     index = ['t1', 't2', 't3', 't4', 't5', 't6'])
print("Original DataFrame:")
print(df)
index = df['weight'].index[df['weight'].isnull()]
index.values.tolist()
# Out:
# Original DataFrame:
#    school_code class            name date_of_birth  weight
# t1        s001     V  Alberto Franco    15/05/2002    35.0
# t2        s002     V    Gino Mcneill    17/05/2002     NaN
# t3        s003    VI     Ryan Parkes    16/02/1999    33.0
# t4        s001    VI    Eesha Hinton    25/09/1998    30.0
# t5        s002     V    Gino Mcneill    11/05/2002    31.0
# t6        s004    VI    David Parkes    15/09/1997     NaN
# ['t2', 't6']

# %%
dt_range = pd.date_range(start ='2020-05-12 07:10:10', freq ='S', periods = 5) 
df = pd.DataFrame([10,20,30,40,50],index=dt_range)
df
# Out:
# C:\Users\VatsalChauhan\AppData\Local\Temp\ipykernel_12044\940760280.py:1: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   dt_range = pd.date_range(start ='2020-05-12 07:10:10', freq ='S', periods = 5)
#                       0
# 2020-05-12 07:10:10  10
# 2020-05-12 07:10:11  20
# 2020-05-12 07:10:12  30
# 2020-05-12 07:10:13  40
# 2020-05-12 07:10:14  50

# %%
import re
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'zefsalf', 'sdfslew', 'zekfsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','05/09/1998','12/02/2022','15/09/1997'],
    'address': ['9910 Surrey <b>Avenue</b>','92 N. Bishop Avenue','9910 <br>Golden Star Avenue', '102 Dunbar <i></i>St.', '17 West Livingston Court']
})

pattern = r'\w+'
print(df)
df['address_without_tags'] = df['address'].apply(lambda x: re.findall(pattern,x))
df
# Out:
#   company_code date_of_sale                      address
# 0         Abcd   12/05/2002    9910 Surrey <b>Avenue</b>
# 1         EFGF   16/02/1999          92 N. Bishop Avenue
# 2      zefsalf   05/09/1998  9910 <br>Golden Star Avenue
# 3      sdfslew   12/02/2022        102 Dunbar <i></i>St.
# 4      zekfsdf   15/09/1997     17 West Livingston Court
#   company_code date_of_sale                      address  \
# 0         Abcd   12/05/2002    9910 Surrey <b>Avenue</b>
# 1         EFGF   16/02/1999          92 N. Bishop Avenue
# 2      zefsalf   05/09/1998  9910 <br>Golden Star Avenue
# 3      sdfslew   12/02/2022        102 Dunbar <i></i>St.
# 4      zekfsdf   15/09/1997     17 West Livingston Court
#
#                address_without_tags
# 0      [9910, Surrey, b, Avenue, b]
# 1           [92, N, Bishop, Avenue]
# 2  [9910, br, Golden, Star, Avenue]
# 3           [102, Dunbar, i, i, St]
# 4     [17, West, Livingston, Court]

# %%
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'zefsalf', 'sdfslew', 'zekfsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','05/09/1998','12/02/2022','15/09/1997'],
    'address': ['9910 Surrey Avenue','92 N. Bishop Avenue','9910 Golden Star Avenue', '102 Dunbar St.', '17 West Livingston Court']
})
df
# Out:
#   company_code date_of_sale                   address
# 0         Abcd   12/05/2002        9910 Surrey Avenue
# 1         EFGF   16/02/1999       92 N. Bishop Avenue
# 2      zefsalf   05/09/1998   9910 Golden Star Avenue
# 3      sdfslew   12/02/2022            102 Dunbar St.
# 4      zekfsdf   15/09/1997  17 West Livingston Court

# %%
pattern = r'[A-Z]\w+'
df['caps_only'] = df['address'].apply(lambda x: re.findall(pattern,x))
df
# Out:
#   company_code date_of_sale                   address  \
# 0         Abcd   12/05/2002        9910 Surrey Avenue
# 1         EFGF   16/02/1999       92 N. Bishop Avenue
# 2      zefsalf   05/09/1998   9910 Golden Star Avenue
# 3      sdfslew   12/02/2022            102 Dunbar St.
# 4      zekfsdf   15/09/1997  17 West Livingston Court
#
#                    caps_only
# 0           [Surrey, Avenue]
# 1           [Bishop, Avenue]
# 2     [Golden, Star, Avenue]
# 3               [Dunbar, St]
# 4  [West, Livingston, Court]

# %%
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'zefsalf', 'sdfslew', 'zekfsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','05/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]
})
df
# Out:
#   company_code date_of_sale  sale_amount
# 0         Abcd   12/05/2002      12348.5
# 1         EFGF   16/02/1999     233331.2
# 2      zefsalf   05/09/1998         22.5
# 3      sdfslew   12/02/2022    2566552.0
# 4      zekfsdf   15/09/1997         23.0

# %%
#format: mm-dd-yyyy
pattern = r'\b(1[0-2]|0[1-9])/(3[01]|[12][0-9]|0[1-9])/([0-9]{4})\b'
df['valid_date'] = df['date_of_sale'].apply(lambda x: re.findall(pattern,x))
df
# Out:
#   company_code date_of_sale  sale_amount        valid_date
# 0         Abcd   12/05/2002      12348.5  [(12, 05, 2002)]
# 1         EFGF   16/02/1999     233331.2                []
# 2      zefsalf   05/09/1998         22.5  [(05, 09, 1998)]
# 3      sdfslew   12/02/2022    2566552.0  [(12, 02, 2022)]
# 4      zekfsdf   15/09/1997         23.0                []

# %%
student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'], 
        'marks': [201, 200, 198, 219, 201]})

print(student_data1)
print(student_data2)
student_data1.merge(student_data2,how='inner',left_on='student_id',right_on='student_id')
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201
#   student_id       name_x  marks_x            name_y  marks_y
# 0         S4    Ed Bernal      222  Scarlette Fisher      201
# 1         S5  Kwame Morin      199  Carla Williamson      200

# %%
df1 = pd.DataFrame({'A': [None, 0, None], 'B': [3, 4, 5]})
df2 = pd.DataFrame({'A': [1, 1, 3], 'B': [3, None, 3]})
print(df1)
print(df2)

df1.combine_first(df2)
# Out:
#      A  B
# 0  NaN  3
# 1  0.0  4
# 2  NaN  5
#    A    B
# 0  1  3.0
# 1  1  NaN
# 2  3  3.0
#      A    B
# 0  1.0  3.0
# 1  0.0  4.0
# 2  3.0  5.0

# %%
data1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'P': ['P0', 'P1', 'P2', 'P3'],
                     'Q': ['Q0', 'Q1', 'Q2', 'Q3']}) 
data2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'R': ['R0', 'R1', 'R2', 'R3'],
                      'S': ['S0', 'S1', 'S2', 'S3']})
print("Original DataFrames:")
print(data1)
print("--------------------")
print(data2)
print("\nMerge two dataframes with different columns:")
result = pd.concat([data1,data2], axis=1)
print(result)
result2 = pd.concat([data1,data2], axis=0)
print(result2)
# Out:
# Original DataFrames:
#   key1 key2   P   Q
# 0   K0   K0  P0  Q0
# 1   K0   K1  P1  Q1
# 2   K1   K0  P2  Q2
# 3   K2   K1  P3  Q3
# --------------------
#   key1 key2   R   S
# 0   K0   K0  R0  S0
# 1   K1   K0  R1  S1
# 2   K1   K0  R2  S2
# 3   K2   K0  R3  S3
#
# Merge two dataframes with different columns:
#   key1 key2   P   Q key1 key2   R   S
# 0   K0   K0  P0  Q0   K0   K0  R0  S0
# 1   K0   K1  P1  Q1   K1   K0  R1  S1
# 2   K1   K0  P2  Q2   K1   K0  R2  S2
# 3   K2   K1  P3  Q3   K2   K0  R3  S3
#   key1 key2    P    Q    R    S
# 0   K0   K0   P0   Q0  NaN  NaN
# 1   K0   K1   P1   Q1  NaN  NaN
# 2   K1   K0   P2   Q2  NaN  NaN
# 3   K2   K1   P3   Q3  NaN  NaN
# 0   K0   K0  NaN  NaN   R0   S0
# 1   K1   K0  NaN  NaN   R1   S1
# 2   K1   K0  NaN  NaN   R2   S2
# 3   K2   K0  NaN  NaN   R3   S3

# %%
df = pd.DataFrame({
'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10','2012-10-05','2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3002,3001,3004,3003,3002,3003,3001],
'salesman_id':[5002,5003,5001,5003,5002,5001,5001,5003,5003,5002,5003,5001]})
print("Original Orders DataFrame:")
print(df)
df.groupby(["customer_id"])['ord_no'].mean()
# Out:
# Original Orders DataFrame:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3002         5002
# 1    70009     270.65  2012-09-10         3001         5003
# 2    70002      65.26  2012-10-05         3001         5001
# 3    70004     110.50  2012-08-17         3003         5003
# 4    70007     948.50  2012-09-10         3002         5002
# 5    70005    2400.60  2012-07-27         3002         5001
# 6    70008    5760.00  2012-09-10         3001         5001
# 7    70010    1983.43  2012-10-10         3004         5003
# 8    70003    2480.40  2012-10-10         3003         5003
# 9    70012     250.45  2012-06-27         3002         5002
# 10   70011      75.29  2012-08-17         3003         5003
# 11   70013    3045.60  2012-04-25         3001         5001
# customer_id
# 3001    70008.00
# 3002    70006.25
# 3003    70006.00
# 3004    70010.00
# Name: ord_no, dtype: float64

# %%
df = pd.DataFrame({
    'student_id': ['S001','S001','S002','S002','S003','S003'],
    'marks': [[88,89,90],[78,81,60],[84,83,91],[84,88,91],[90,89,92],[88,59,90]]})
print("Original DataFrame:")
rs = df.groupby(["student_id"])['marks'].apply(list).apply(lambda x:np.mean(x,0))

rs
# Out:
# Original DataFrame:
# student_id
# S001    [83.0, 85.0, 75.0]
# S002    [84.0, 85.5, 91.0]
# S003    [89.0, 74.0, 91.0]
# Name: marks, dtype: object

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'weight': [173, 192, 186, 167, 151, 159],
    'height': [35, None, 33, 30, None, 32]},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    school_code class            name date_Of_Birth   age  weight  height
# S1        s001     V  Alberto Franco     15/05/2002   12     173    35.0
# S2        s002     V    Gino Mcneill     17/05/2002   12     192     NaN
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186    33.0
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167    30.0
# S5        s002     V    Gino Mcneill     11/05/2002   14     151     NaN
# S6        s004    VI    David Parkes     15/09/1997   12     159    32.0

# %%
ls = df[df['height'].isnull()].index
for i in ls:
    df.drop(i,inplace=True)
df
# Out:
#    school_code class            name date_Of_Birth   age  weight  height
# S1        s001     V  Alberto Franco     15/05/2002   12     173    35.0
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186    33.0
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167    30.0
# S6        s004    VI    David Parkes     15/09/1997   12     159    32.0

# %%
df = pd.read_csv("world_alcohol.csv")
df[1::5].head(5)
# Out:
#     Year WHO region     Country Beverage Types  Display Value
# 1   1986   Americas     Uruguay          Other           0.50
# 6   1987     Africa   Mauritius           Wine           0.13
# 11  1989   Americas   Guatemala           Beer           0.62
# 16  1984   Americas  Costa Rica           Wine           0.06
# 21  1989   Americas  Costa Rica        Spirits           4.51

# %%
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFind  all columns which all entries present:")
print(w_a_con.loc[:, w_a_con.notnull().all()])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Find  all columns which all entries present:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ...

# %%
df = pd.DataFrame({
'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10','2012-10-05','2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3002,3001,3004,3003,3002,3003,3001],
'salesman_id':[5002,5003,5001,5003,5002,5001,5001,5003,5003,5002,5003,5001]})
print("Original Orders DataFrame:")
df.groupby(['customer_id'])['customer_id'].count()
# Out:
# Original Orders DataFrame:
# customer_id
# 3001    4
# 3002    4
# 3003    3
# 3004    1
# Name: customer_id, dtype: int64

# %%
df.drop(df.groupby(['customer_id']).tail(1).index,inplace=True)
df.groupby(['customer_id'])['customer_id'].count()
# Out:
# customer_id
# 3001    3
# 3002    3
# 3003    2
# Name: customer_id, dtype: int64

# %%
df = pd.DataFrame({
'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10','2012-10-05','2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3005,3001,3002,3009,3005,3007,3002,3004,3009,3008,3003,3002],
'salesman_id': [5002,5005,5001,5003,5002,5001,5001,5004,5003,5002,5004,5001]})
print("Original Orders DataFrame:")
print(df)
# Out:
# Original Orders DataFrame:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3005         5002
# 1    70009     270.65  2012-09-10         3001         5005
# 2    70002      65.26  2012-10-05         3002         5001
# 3    70004     110.50  2012-08-17         3009         5003
# 4    70007     948.50  2012-09-10         3005         5002
# 5    70005    2400.60  2012-07-27         3007         5001
# 6    70008    5760.00  2012-09-10         3002         5001
# 7    70010    1983.43  2012-10-10         3004         5004
# 8    70003    2480.40  2012-10-10         3009         5003
# 9    70012     250.45  2012-06-27         3008         5002
# 10   70011      75.29  2012-08-17         3003         5004
# 11   70013    3045.60  2012-04-25         3002         5001

# %%
df.groupby(['salesman_id'])['ord_date'].min()
# Out:
# salesman_id
# 5001    2012-04-25
# 5002    2012-06-27
# 5003    2012-08-17
# 5004    2012-08-17
# 5005    2012-09-10
# Name: ord_date, dtype: object

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
plt.figure(figsize=(8,5))
print(df)
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu")
plt.show()
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720

# %%
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color
print("\nNegative numbers red and positive numbers black:")
df.style.applymap(color_negative_red)
# Out:
# Negative numbers red and positive numbers black:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\VatsalChauhan\anaconda3\Lib\site-packages\pandas\io\formats\style.py in ?(self)
#     401         Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     402         default if an object is returned at the end of a cell.
#     403         """
#     404         if get_option("styler.render.repr") == "html":
# --> 405             return self.to_html()
#     406         return None
#
# c:\Users\VatsalChauhan\anaconda3\Lib\site-packages\pandas\io\formats\style.py in ?(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1341         if caption is not None:
#    1342             obj.set_caption(caption)
#    1343
# ...

# %%
df1 = pd.read_excel('employee.xlsx',sheet_name=0)
df2 = pd.read_excel('employee.xlsx',sheet_name=1)
df3 = pd.read_excel('employee.xlsx',sheet_name=2)
pd.concat([df1,df2,df3])
# Out:
#     emp_id   first_name    last_name  hire_date
# 0      100       Steven         King 2003-06-17
# 1      101        Neena      Kochhar 2005-09-21
# 2      102          Lex      De Haan 2001-01-13
# 3      103    Alexander       Hunold 2006-01-03
# 4      104        Bruce        Ernst 2007-05-21
# 5      105        David       Austin 2005-06-25
# 6      106        Valli    Pataballa 2006-02-05
# 7      107        Diana      Lorentz 2007-02-07
# 8      108        Nancy    Greenberg 2002-08-17
# 9      109       Daniel       Faviet 2002-08-16
# 10     110         John         Chen 2005-09-28
# 11     111       Ismael      Sciarra 2005-09-30
# 12     112  Jose Manuel        Urman 2006-03-07
# 13     113         Luis         Popp 2007-12-07
# 14     114          Den     Raphaely 2002-12-07
# 15     115    Alexander         Khoo 2003-05-18
# 16     116       Shelli        Baida 2005-12-24
# 17     117        Sigal       Tobias 2005-07-24
# 18     118          Guy       Himuro 2006-11-15
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('employee.xlsx')
df2 = df.set_index(['hire_date'])


# Filter the rows for the year 2005
result = df2[df2.index == 2005]

# Display the result
print(result)
# Out:
# Empty DataFrame
# Columns: [emp_id, first_name, last_name]
# Index: []

# %%
df
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      100       Steven        King 2003-06-17
# 1      101        Neena     Kochhar 2005-09-21
# 2      102          Lex     De Haan 2001-01-13
# 3      103    Alexander      Hunold 2006-01-03
# 4      104        Bruce       Ernst 2007-05-21
# 5      105        David      Austin 2005-06-25
# 6      106        Valli   Pataballa 2006-02-05
# 7      107        Diana     Lorentz 2007-02-07
# 8      108        Nancy   Greenberg 2002-08-17
# 9      109       Daniel      Faviet 2002-08-16
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 12     112  Jose Manuel       Urman 2006-03-07
# 13     113         Luis        Popp 2007-12-07
# 14     114          Den    Raphaely 2002-12-07
# 15     115    Alexander        Khoo 2003-05-18
# 16     116       Shelli       Baida 2005-12-24
# 17     117        Sigal      Tobias 2005-07-24
# 18     118          Guy      Himuro 2006-11-15
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("world_alcohol.csv")
df.set_index('Year',inplace=True)

# %%
df.replace({
    'Africa':'India',
    'Other':np.NaN
})
# Out:
#            WHO region                                Country Beverage Types  \
# Year
# 1986  Western Pacific                               Viet Nam           Wine
# 1986         Americas                                Uruguay            NaN
# 1985            India                           Cte d'Ivoire           Wine
# 1986         Americas                               Colombia           Beer
# 1987         Americas                  Saint Kitts and Nevis           Beer
# ...               ...                                    ...            ...
# 1984            India                                  Niger            NaN
# 1985           Europe                             Luxembourg           Wine
# 1984  South-East Asia                              Indonesia           Wine
# 1984            India                      Equatorial Guinea           Wine
# 1985  South-East Asia  Democratic People's Republic of Korea           Wine
#
#       Display Value
# Year
# 1986           0.00
# ...

# %%
data1 =  {'name':['vatsal','vraj','aneri','prince'],
    'age':[21,22,np.NaN,24],
    'city':['bharuch','Navsari',np.NaN,np.NaN]
}
data2 = {'name':['manavni','sahil','jeet','prince'],
    'age':[21,22,np.NaN,24],
    'city':['bharuch','Navsari',np.NaN,35],
    'office':['crest','crest','crest',np.NaN]
}
df2 = pd.DataFrame(data2)
df1 = pd.DataFrame(data1)

temp_df=pd.concat([df1,df2],keys=['old','new'])
temp_df.fillna({
    'city':'Not available',
    'age':temp_df['age'].mean()
}
,inplace=True)
temp_df['age']=temp_df['age'].astype(int)
temp_df
# Out:
#           name  age           city office
# old 0   vatsal   21        bharuch    NaN
#     1     vraj   22        Navsari    NaN
#     2    aneri   22  Not available    NaN
#     3   prince   24  Not available    NaN
# new 0  manavni   21        bharuch  crest
#     1    sahil   22        Navsari  crest
#     2     jeet   22  Not available  crest
#     3   prince   24             35    NaN

# %%
temp_df.loc[temp_df['name']=='vraj','office']='crest'
temp_df
# Out:
#           name  age           city office
# old 0   vatsal   21        bharuch    NaN
#     1     vraj   22        Navsari  crest
#     2    aneri   22  Not available    NaN
#     3   prince   24  Not available    NaN
# new 0  manavni   21        bharuch  crest
#     1    sahil   22        Navsari  crest
#     2     jeet   22  Not available  crest
#     3   prince   24             35    NaN

# %%
data1 =  {'name':['vatsal','vraj','aneri','prince'],
    'age':[21,22,np.NaN,24],
    'city':['bharuch','Navsari',np.NaN,np.NaN]
}
data2 = {'name':['manavni','sahil','jeet','prince'],
    'age':[21,22,np.NaN,24],
    'city':['bharuch','Navsari',np.NaN,'jamnabag'],
    'office':['crest','crest','crest',np.NaN]
}
df2 = pd.DataFrame(data2)
df1 = pd.DataFrame(data1)
print(df1)
print("\n")
print(df2)
print("\n")


temp = pd.concat([df1,df2]).fillna({
    'office':'no placement'
})

temp.replace({
    'no placement':'Meditab'
})
# Out:
#      name   age     city
# 0  vatsal  21.0  bharuch
# 1    vraj  22.0  Navsari
# 2   aneri   NaN      NaN
# 3  prince  24.0      NaN
#
#
#       name   age      city office
# 0  manavni  21.0   bharuch  crest
# 1    sahil  22.0   Navsari  crest
# 2     jeet   NaN       NaN  crest
# 3   prince  24.0  jamnabag    NaN
#       name   age      city   office
# 0   vatsal  21.0   bharuch  Meditab
# 1     vraj  22.0   Navsari  Meditab
# 2    aneri   NaN       NaN  Meditab
# 3   prince  24.0       NaN  Meditab
# 0  manavni  21.0   bharuch    crest
# 1    sahil  22.0   Navsari    crest
# 2     jeet   NaN       NaN    crest
# 3   prince  24.0  jamnabag  Meditab

# %%
df = pd.read_csv("C:/Users/VatsalChauhan/Downloads/aapl.csv",parse_dates=['Date'])
df.set_index('Date',inplace=True)
df.sort_index(inplace=True)
df.loc["2017-01":"2017-02"]
# Out:
# C:\Users\VatsalChauhan\AppData\Local\Temp\ipykernel_8216\673424329.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("C:/Users/VatsalChauhan/Downloads/aapl.csv",parse_dates=['Date'])
#               Open    High     Low   Close     Volume
# Date
# 2017-01-03  115.80  116.33  114.76  116.15   28781865
# 2017-01-04  115.85  116.51  115.75  116.02   21118116
# 2017-01-05  115.92  116.86  115.81  116.61   22193587
# 2017-01-06  116.78  118.16  116.47  117.91   31751900
# 2017-01-09  117.95  119.43  117.94  118.99   33561948
# 2017-01-10  118.77  119.38  118.30  119.11   24462051
# 2017-01-11  118.74  119.93  118.60  119.75   27588593
# 2017-01-12  118.90  119.30  118.21  119.25   27086220
# 2017-01-13  119.11  119.62  118.81  119.04   26111948
# 2017-01-17  118.34  120.24  118.22  120.00   34439843
# ...

# %%
'''
time series 
'''
df = pd.date_range(start='01-05-2015',end='01-31-2015',freq='B')
df
# Out:
# DatetimeIndex(['2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-12', '2015-01-13', '2015-01-14',
#                '2015-01-15', '2015-01-16', '2015-01-19', '2015-01-20',
#                '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-26',
#                '2015-01-27', '2015-01-28', '2015-01-29', '2015-01-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
'''
period 
'''
df_time = pd.Period('2017','M')
print(df_time.start_time)
df_time.end_time
# Out:
# 2017-01-01 00:00:00
# Timestamp('2017-01-31 23:59:59.999999999')

# %%
'''
Write a Pandas program to calculate percentage change in Resampled data. 
'''
date_rng = pd.date_range(start='2021-01-01', end='2021-01-10', freq='D')
ts = pd.Series(np.random.randn(len(date_rng)), index=date_rng)
dff = pd.DataFrame(ts,columns=["data"],index=date_rng)
dff.resample('H').mean()
# Out:
# C:\Users\VatsalChauhan\AppData\Local\Temp\ipykernel_8216\2198644434.py:7: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dff.resample('H').mean()
#                          data
# 2021-01-01 00:00:00 -0.213694
# 2021-01-01 01:00:00       NaN
# 2021-01-01 02:00:00       NaN
# 2021-01-01 03:00:00       NaN
# 2021-01-01 04:00:00       NaN
# ...                       ...
# 2021-01-09 20:00:00       NaN
# 2021-01-09 21:00:00       NaN
# 2021-01-09 22:00:00       NaN
# 2021-01-09 23:00:00       NaN
# 2021-01-10 00:00:00  0.157917
#
# [217 rows x 1 columns]

# %%
'''
Write a Pandas program to create custom Resampling periods. 
'''
date_rng = pd.date_range(start='2021-01-01', end='2021-01-10', freq='D')
ts = pd.Series(np.random.randn(len(date_rng)), index=date_rng)
dff = pd.DataFrame(ts,columns=["data"],index=date_rng)





def custom_resampleing(ts,freq):
    return ts.groupby(pd.Grouper(freq=freq)).mean()


result_sampling = custom_resampleing(ts,'2D')
result_sampling
# Out:
# 2021-01-01    0.147363
# 2021-01-03   -0.227871
# 2021-01-05   -0.933283
# 2021-01-07   -0.274881
# 2021-01-09   -0.331291
# Freq: 2D, dtype: float64

# %%
dff
# Out:
#                 data
# 2021-01-01 -0.392946
# 2021-01-02  0.687672
# 2021-01-03 -0.425664
# 2021-01-04 -0.030077
# 2021-01-05 -0.635879
# 2021-01-06 -1.230687
# 2021-01-07  0.634429
# 2021-01-08 -1.184192
# 2021-01-09  0.071545
# 2021-01-10 -0.734126

# %%
df = pd.read_csv("temp.csv")

# %%
df
# Out:
#                 id       Column1       Column2       Column3       Column4  \
# 0  ['1', '2', '3']  [33, 25, 56]  [35, 30, 30]  [21, 40, 55]  [71, 25, 55]
# 1  ['1', '2', '3']  [33, 25, 56]  [35, 30, 30]  [21, 40, 55]  [71, 25, 55]
# 2  ['1', '2', '3']  [33, 25, 56]  [35, 30, 30]  [21, 40, 55]  [71, 25, 55]
# 3  ['1', '2', '3']  [33, 25, 56]  [35, 30, 30]  [21, 40, 55]  [71, 25, 55]
# 4  ['1', '2', '3']  [33, 25, 56]  [35, 30, 30]  [21, 40, 55]  [71, 25, 55]
# 5  ['1', '2', '3']  [33, 25, 56]  [35, 30, 30]  [21, 40, 55]  [71, 25, 55]
#
#         Column5
# 0  [10, 10, 40]
# 1  [10, 10, 40]
# 2  [10, 10, 40]
# 3  [10, 10, 40]
# 4  [10, 10, 40]
# 5  [10, 10, 40]

# %%
df = pd.read_csv("C:/Users/VatsalChauhan/Downloads/aapl.csv",parse_dates=['Date'])
df.set_index('Date',inplace=True)
df
# Out:
# C:\Users\VatsalChauhan\AppData\Local\Temp\ipykernel_8216\909859291.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("C:/Users/VatsalChauhan/Downloads/aapl.csv",parse_dates=['Date'])
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# ...

# %%
dtypes = {
    'Open': 'float64',  # Change to float64 if the data contains decimals
    'High': 'float64',
    'Low': 'float64',
    'Close': 'float64',
    'Volume': 'object',
}

# Specify the columns to read (make sure they match the CSV file)
usecols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']

# Read the CSV with updated dtype
df = pd.read_csv("C:/Users/VatsalChauhan/Downloads/aapl.csv", parse_dates=['Date'], dtype=dtypes, usecols=usecols)

# Display the DataFrame
print(df)
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]
# C:\Users\VatsalChauhan\AppData\Local\Temp\ipykernel_8216\3510709764.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
''' 
GroupBy and Applying Multiple Aggregations with Named Functions:
Write a Pandas program to apply multiple aggregations with named functions in GroupBy for detailed data analysis.
'''
data = {'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
        'Value1': [5, 10, 15, 20, 25, 30],
        'Value2': [50, 100, 150, 200, 250, 300]}

df = pd.DataFrame(data)
date_df = pd.DataFrame(pd.date_range(start='2025-01-01',periods=len(df)),columns=['Date'])
print("Sample DataFrame:")
print(df)
dff = pd.concat([df,date_df],axis=1)
dff.set_index('Date',inplace=True)
dff
# Out:
# Sample DataFrame:
#   Category  Value1  Value2
# 0        A       5      50
# 1        A      10     100
# 2        B      15     150
# 3        B      20     200
# 4        C      25     250
# 5        C      30     300
#            Category  Value1  Value2
# Date
# 2025-01-01        A       5      50
# 2025-01-02        A      10     100
# 2025-01-03        B      15     150
# 2025-01-04        B      20     200
# 2025-01-05        C      25     250
# 2025-01-06        C      30     300

# %%
dff.groupby(['Category']).agg(
    Total_Value1=('Value1', 'sum'),
    Average_Value2=('Value2', 'mean'),
    variance = ('Value1','std')
)
# Out:
#           Total_Value1  Average_Value2  variance
# Category
# A                   15            75.0  3.535534
# B                   35           175.0  3.535534
# C                   55           275.0  3.535534

# %%
'''
pandas practice set
'''
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
diamonds[diamonds.clarity.duplicated()]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53932 rows x 10 columns]

# %%
data = {'X': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar'], 'Y': range(10)}
df = pd.DataFrame(data)
data
# Out:
# {'X': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar'],
#  'Y': range(0, 10)}

# %%
import pandas as pd
import numpy as np
data = np.random.randint(1,5,size=(20,3))
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
df
# Out:
#     X  Y  Z
# 0   2  3  1
# 1   2  1  4
# 2   3  2  2
# 3   2  4  3
# 4   3  4  4
# 5   3  3  2
# 6   3  4  4
# 7   3  2  2
# 8   1  4  2
# 9   3  1  1
# 10  3  2  2
# 11  1  4  1
# 12  2  2  1
# 13  4  3  3
# 14  4  2  1
# 15  2  2  2
# 16  2  1  4
# 17  1  2  2
# 18  1  3  1
# 19  2  4  4

# %%
df['std'] = df.groupby('X')['Y'].rolling(window=3).std().reset_index(level=0, drop=True)
df
# Out:
#     X  Y  Z       std
# 0   2  3  1       NaN
# 1   2  1  4       NaN
# 2   3  2  2       NaN
# 3   2  4  3  1.527525
# 4   3  4  4       NaN
# 5   3  3  2  1.000000
# 6   3  4  4  0.577350
# 7   3  2  2  1.000000
# 8   1  4  2       NaN
# 9   3  1  1  1.527525
# 10  3  2  2  0.577350
# 11  1  4  1       NaN
# 12  2  2  1  1.527525
# 13  4  3  3       NaN
# 14  4  2  1       NaN
# 15  2  2  2  1.154701
# 16  2  1  4  0.577350
# 17  1  2  2  1.154701
# 18  1  3  1  1.000000
# 19  2  4  4  1.527525
